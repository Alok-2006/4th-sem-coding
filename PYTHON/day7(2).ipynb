# %%
text = "384859"
modified_text= text.replace(9,3)
print(text)
print(modified_text)

# %%
---------------------------------------------------------------------------
TypeError                                 Traceback (most recent call last)
Cell In[3], line 2
      1 text = "384859"
----> 2 modified_text= text.replace(9,3)
      3 print(text)
      4 print(modified_text)

TypeError: replace() argument 1 must be str, not int

# %%
x="hello,everyone.lets,learn,python."
x.replace("$", ".")
x.replace(",", ".")
x.replace("$", ",")
print(x)
