# %%
lst= [1,2,3,"hello,5,7"]
print(lst)
lst[-2]="Hii"
for i in range(len(lst)):
    print(lst[i],end=" ")
# Out:
# [1, 2, 3, 'hello,5,7']
# 1 2 Hii hello,5,7

# %%
lst=[1,2,3,"hello",5,7]
for i in lst:
    print(i)
# Out:
# 1
# 2
# 3
# hello
# 5
# 7

# %%
lst=eval(input("Enter a list: "))
print(lst)
print(type(lst))
# Out:
# Traceback (most recent call last):
#
#   File ~\AppData\Roaming\Python\Python314\site-packages\IPython\core\interactiveshell.py:3747 in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#
#   Cell In[9], line 1
#     lst=eval(input("Enter a list:  "))
#
#   File <string>
#
#     ^
# SyntaxError: invalid syntax

# %%
# Write a program which will take list as a input from and increase all the even no. by 5 and decrease all the odd no. by 5



lst=eval(input("Enter a list: "))
print(lst)
for i in range(len(lst)):
    if lst[i]%2 == 0:
        lst[i] += 5
    else:
        lst[i] -= 5
print(lst)
